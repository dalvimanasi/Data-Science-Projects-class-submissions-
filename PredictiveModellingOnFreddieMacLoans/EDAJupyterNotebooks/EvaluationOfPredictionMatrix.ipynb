# %% [markdown]
# # Evaluation of Prediction Algorithm run on different quarters

# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
MATRIXPATH=MAINPATH=os.environ['DATAPATH']+"/RegressionMetrics.csv"

# %%
#MATRIXPATH="C:/Users/visha/Desktop/MSIS/Advanced Data Science/Assignments/MIDTERM/Part2/RegressionMetrics.csv"
SHORTMATRIXPATH="C:/Users/visha/Desktop/MSIS/Advanced Data Science/Assignments/MIDTERM/Part2/RegressionMetrics-Short.csv"
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ### Financial Boom 1999 - 2013

# %%
evalmatrix_df=pd.read_csv(MATRIXPATH)
evalmatrix_df.index=evalmatrix_df['TestQuarter']
evalmatrix_df
# Out:
#             TrainQuarter TestQuarter  R-squared       MSE      RMSE       MAE  \
# TestQuarter
# Q21999            Q11999      Q21999  -0.160333  0.166848  0.408470  0.307175
# Q31999            Q21999      Q31999  -1.638772  0.509913  0.714082  0.621578
# Q41999            Q31999      Q41999   0.146281  0.138563  0.372241  0.276042
# Q12000            Q41999      Q12000  -0.252923  0.247960  0.497955  0.411462
# Q22000            Q12000      Q22000   0.235048  0.172866  0.415771  0.311135
# Q32000            Q22000      Q32000   0.134150  0.186684  0.432069  0.332261
# Q42000            Q32000      Q42000  -0.257802  0.272939  0.522435  0.422147
# Q12001            Q42000      Q12001  -2.920549  0.688960  0.830036  0.758795
# Q22001            Q12001      Q22001   0.213405  0.101241  0.318185  0.235043
# Q32001            Q22001      Q32001   0.275709  0.098679  0.314132  0.233414
# Q42001            Q32001      Q42001  -0.951389  0.247532  0.497526  0.427260
# ...

# %% [markdown]
# ### Variation of R squared

# %%
evalmatrix_df['R-squared'].plot(kind='bar',figsize=((20,10)),title='Variation of R-squared')
plt.show()

# %% [markdown]
# ### Variation of MAPE

# %%
evalmatrix_df['MAPE'].plot(kind='line',figsize=((20,10)),title='Variation of MAPE')
plt.show()

# %% [markdown]
# ### Variation of MSE, RMSE, MAE

# %%
evalmatrix_df[['MSE','RMSE','MAE']].plot(kind='line',figsize=((20,10)),title='Variation MSE,RMSE,MAE by quarter')
plt.show()

# %% [markdown]
# ### 2007-2009

# %%
evalmatrixshort_df=pd.read_csv(SHORTMATRIXPATH)
evalmatrixshort_df.index=evalmatrixshort_df['TestQuarter']
evalmatrixshort_df
# Out:
#             TrainQuarter TestQuarter  R-squared       MSE      RMSE       MAE  \
# TestQuarter
# Q22007            Q12007      Q22007   0.248759  0.115398  0.339703  0.256191
# Q22007            Q12007      Q22007   0.248110  0.115498  0.339850  0.256373
# Q32007            Q22007      Q32007  -0.495262  0.222384  0.471576  0.393692
# Q42007            Q32007      Q42007  -0.119694  0.219287  0.468281  0.381285
# Q12008            Q42007      Q12008  -0.250048  0.318597  0.564444  0.478491
# Q22008            Q12008      Q22008   0.355858  0.144800  0.380526  0.288959
# Q32008            Q22008      Q32008  -0.157261  0.244770  0.494743  0.412042
# Q42008            Q32008      Q42008  -0.267353  0.451529  0.671959  0.547267
# Q12009            Q42008      Q12009  -4.072287  0.686869  0.828775  0.760595
# Q22009            Q12009      Q22009   0.247775  0.089017  0.298357  0.228486
# Q32009            Q22009      Q32009   0.064806  0.159190  0.398986  0.321685
# ...

# %%
evalmatrixshort_df['R-squared'].plot(kind='bar',figsize=((20,10)),title='Variation of R-squared')
plt.show()

# %%
evalmatrixshort_df['MAPE'].plot(kind='line',figsize=((20,10)),title='Variation of MAPE')
plt.show()

# %%
evalmatrixshort_df[['MSE','RMSE','MAE']].plot(kind='line',figsize=((20,10)),title='Variation MSE,RMSE,MAE by quarter')
plt.show()
