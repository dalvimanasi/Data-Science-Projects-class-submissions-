# %% [markdown]
# # Methods to connect to Zillow API
#
# This document illustrates all the different methods supported by the Zillow API developed by Team 1
#
# API Details :
#
# **URL** : http://zillowwebapp-receptive-ens.mybluemix.net
#
# **Resources supported **:
#
# * searchclosestgeo - API to search closest 10 properties
# * search - to search data based on parameters (including parcel id search)
# * propertydesc - fetches the descriptions of all property types or a specific ID
# * heatingsystemtype - fetches the descriptions of all heating system types or a specific ID
# * airconditiontype - fetches the descriptions of all the Airconditioning types or a specific ID
# * propertybyyear - Used to query the number of properties grouped by the year they were buit in or a specific ID
# * propertytax - Provides the min,max,avg tax value associated with a particular type of property or a specific ID
#
#
# #### Method : GET
# Since all the queries are search queries and no update / delete queries.
# The only method supported in the **GET** method
#
# #### Sample output format
#
# {
#   "Message": "Success",
#   "Status": 200,
#   "results": [
#       <list of results>
#   ]
# }
#
# {
#   "Message": "No records close to the entered location",
#   "Status": 204,
#   "results": []
# }
#
# #### Status codes
# 200 - Status Success
# 204 - No Records found
# 5xx - Error messages for business validations

# %%
import pandas as pd
import json, requests
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Enhanced Geospatial Search, Closest Homes
# We can query the API to fetch the 10 closest homes near the location provided as parameters in the get query

# %%
url='http://zillowwebapp-receptive-ens.mybluemix.net/searchclosestgeo'
params = dict(
    latitude=34.44524,
    longitude=-118.535323
)
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)
print(data['Status'])
print(data['Message'])
df=pd.DataFrame(data['results'])
df
# Out:
# 200
# Success
#    Bathrooms  Bedrooms      City       County  Distance in meters   Latitude  \
# 0        3.0       4.0  Valencia  Los Angeles             155.270  34.445143
# 1        3.0       3.0  Valencia  Los Angeles             165.566  34.444991
# 2        3.0       3.0  Valencia  Los Angeles             177.427  34.444853
# 3        3.0       3.0  Valencia  Los Angeles             184.087  34.445282
# 4        3.0       3.0  Valencia  Los Angeles             193.350  34.444742
# 5        3.0       3.0  Valencia  Los Angeles             205.373  34.444185
# 6        3.0       3.0  Valencia  Los Angeles             209.107  34.444616
# 7        3.0       3.0  Valencia  Los Angeles             209.983  34.443876
# 8        3.0       4.0  Valencia  Los Angeles             211.797  34.446505
# 9        2.0       3.0  Valencia  Los Angeles             215.807  34.446643
#
#     Longitude Neighborhood       State  Total Area Zipcode  parcelid
# 0 -118.536716               California      3556.0   91354  11112172
# 1 -118.536791               California      2559.0   91354  11112134
# 2 -118.536871               California      3184.0   91354  11112135
# 3 -118.536978               California      2730.0   91354  11112171
# 4 -118.536989               California      2730.0   91354  11112136
# 5 -118.536839               California      3184.0   91354  11112157
# 6 -118.537097               California      2730.0   91354  11112137
# 7 -118.536629               California      2730.0   91354  11112158
# 8 -118.536747               California      2297.0   91354  11111288
# 9 -118.536664               California      1245.0   91354  11111283

# %%
import folium
#map_osm = folium.Map(location=[45.5236, -122.6750])
map_1 = folium.Map(location=[df.Latitude.mean(),df.Longitude.mean()], zoom_start=15)
for row in df.index:
    #change the column indices later
    popup="Distance : "+str(df.iloc[row]['Distance in meters'])+" metres. Parcel ID : "+str(df.iloc[row].parcelid)+". Neighborhood : "+str(df.iloc[row].Neighborhood)+". City : "+str(df.iloc[row].City)+". Zipcode : "+str(df.iloc[row].Zipcode)
    folium.Marker([float(df.iloc[row].Latitude),float(df.iloc[row].Longitude)], popup=popup).add_to(map_1)
map_1.save("closest10.html")

# %%
# %%HTML
# <iframe width ="100%" height=300 src="closest10.html"></iframe>
# Out:
# <iframe width ="100%" height=300 src="closest10.html"></iframe>

# %% [markdown]
# ## Search
# We can query the api using the search url to perform  a search based on the following parameters.
#
# Since the dataset size is huge, this **search API only returns 100 records at a time**. You can request for the next set of 100 records using the start parameter.
#
# **API URL**
#
#
# **Parameters For the API** (Atleast one parameter is required)
# * parcelid
# * zipcode (int)
# * bathroom (int/float)
# * totalarea (float)
# * bedroom (int/float)
# * yearbuilt (int)
# * pool (int)
# * heating (int)
# * storeys (int)
# * propertytype (int)
# * aircondition (int)
# * start (int) greater than 0 - This is the offset and indicates the index for the next set of results.
#
# Values are returned in json and can be used directly in a dataframe

# %% [markdown]
# Query on parcelid (property id)

# %%
url = 'http://zillowwebapp-receptive-ens.mybluemix.net/search'
params = dict(
    parcelid=14397743,
)
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)
print(data['Status'])
print(data['Message'])
df=pd.DataFrame(data['results'])
df
# Out:
# 200
# Success
#   AirConditioning  AirConditioningID  AssessmentYear  Bathrooms  Bedrooms  \
# 0         Central                  1            2015        2.0       3.0
#
#   BuildingQuality  FIPS  Garage  HeatingID HeatingSystem  Latitude  \
# 0            None  6059     2.0          6    Forced air  33.54709
#
#    LivingArea   Longitude  NumberOfStories  ParcelID  Pool  \
# 0      2048.0 -117.687917                1  14397743  None
#
#                 PropertyType  PropertyTypeID  TaxAssessedOnStructure  \
# 0  Single Family Residential             261                128128.0
#
#    TotalTaxAssessed  TotalTaxForAssessmentYear  YearBuilt    ZIP
# 0          167070.0                    1735.12       1978  96987

# %%
url = 'http://zillowwebapp-receptive-ens.mybluemix.net/search'
params = dict(
    #parcelid=14397743,
    zipcode=96987,
    bathroom=2.0,
    #totalarea=,
    #bedroom=1.0,
    #yearbuilt=1950,
    #pool=1.0,
    heating=6,
    #storeys=1,
    #propertytype=261,
    aircondition=1,
    start=0
)
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)
print(data['Status'])
print(data['Message'])
df=pd.DataFrame(data['results'])
df
# Out:
# 200
# Success
#    AirConditioning  AirConditioningID  AssessmentYear  Bathrooms  Bedrooms  \
# 0          Central                  1            2015        2.0       3.0
# 1          Central                  1            2015        2.0       3.0
# 2          Central                  1            2015        2.0       2.0
# 3          Central                  1            2015        2.0       3.0
# 4          Central                  1            2015        2.0       2.0
# 5          Central                  1            2015        2.0       3.0
# 6          Central                  1            2015        2.0       3.0
# 7          Central                  1            2015        2.0       3.0
# 8          Central                  1            2015        2.0       3.0
# 9          Central                  1            2015        2.0       3.0
# 10         Central                  1            2015        2.0       3.0
# 11         Central                  1            2015        2.0       3.0
# 12         Central                  1            2015        2.0       4.0
# 13         Central                  1            2015        2.0       3.0
# 14         Central                  1            2015        2.0       2.0
# 15         Central                  1            2015        2.0       3.0
# 16         Central                  1            2015        2.0       3.0
# 17         Central                  1            2015        2.0       1.0
# 18         Central                  1            2015        2.0       2.0
# 19         Central                  1            2015        2.0       4.0
# 20         Central                  1            2015        2.0       5.0
# 21         Central                  1            2015        2.0       3.0
# 22         Central                  1            2015        2.0       3.0
# 23         Central                  1            2015        2.0       2.0
# 24         Central                  1            2015        2.0       2.0
# 25         Central                  1            2015        2.0       2.0
# 26         Central                  1            2015        2.0       2.0
# 27         Central                  1            2015        2.0       1.0
# 28         Central                  1            2015        2.0       2.0
# 29         Central                  1            2015        2.0       3.0
# 30         Central                  1            2015        2.0       3.0
# 31         Central                  1            2015        2.0       3.0
# 32         Central                  1            2015        2.0       3.0
# 33         Central                  1            2015        2.0       2.0
# 29      1216.0 -117.718909              1.0  14632273   NaN
# 30      1694.0 -117.714391              1.0  14655112   NaN
# 31      2418.0 -117.683832              2.0  14398020   1.0
# 32      1592.0 -117.676282              1.0  14398705   NaN
# 33      1148.0 -117.688706              NaN  14398867   NaN
# 34      1702.0 -117.689269              NaN  14742676   NaN
# 35      1893.0 -117.704286              1.0  14414148   1.0
# 36      1353.0 -117.713873              1.0  14655186   NaN
# 37      1148.0 -117.689307              NaN  14398862   NaN
# 38      1460.0 -117.718823              1.0  14417157   NaN
# 39       865.0 -117.682381              1.0  14627442   1.0
# 40      1450.0 -117.705101              2.0  14410214   NaN
# 41      1893.0 -117.703272              1.0  14414287   1.0
# 42      1428.0 -117.728587              1.0  14420964   NaN
# 43      1406.0 -117.698087              NaN  14416596   NaN
# 44      1877.0 -117.728077              1.0  14420596   NaN
# 45      2319.0 -117.701001              NaN  14416797   NaN
# 46      1353.0 -117.714390              1.0  14655160   1.0
# 47      1702.0 -117.687826              NaN  14742445   NaN
# 48      1421.0 -117.689174              1.0  14397473   NaN
# 49      1462.0 -117.702090              NaN  14416554   NaN
# 50      2000.0 -117.705225              2.0  14414159   1.0
# 51      1210.0 -117.693162              1.0  14415684   1.0
# 52      1642.0 -117.726696              1.0  14420470   NaN
# 53      1368.0 -117.707904              1.0  14652105   1.0
# 54      1814.0 -117.702202              2.0  14411054   NaN
# 55      1696.0 -117.681548              1.0  14398605   1.0
# 56      1406.0 -117.693112              1.0  14415800   NaN
# 57      1122.0 -117.715602              1.0  14635370   1.0
# 58       939.0 -117.693799              1.0  14653999   1.0
# 59      1738.0 -117.686588              1.0  14397358   NaN
# 60      1787.0 -117.690606              NaN  14416001   NaN
# 61      2048.0 -117.685739              1.0  14397756   1.0
# 62      2210.0 -117.710864              1.0  14414955   NaN
# 63      2324.0 -117.709755              1.0  14411352   1.0
# 64      1078.0 -117.689072              NaN  14651833   NaN
# 65      1078.0 -117.689142              NaN  14651812   NaN
# 66      2418.0 -117.682807              2.0  14398074   NaN
# 67       942.0 -117.693251              NaN  14398942   NaN
# 68      1819.0 -117.719272              1.0  14417574   NaN
# 69      1602.0 -117.728778              1.0  14420560   NaN
# 70      1738.0 -117.685732              1.0  14397311   NaN
# 71      1830.0 -117.701922              2.0  14411066   1.0
# 72      1738.0 -117.712138              1.0  14413897   NaN
# 73      1710.0 -117.723500              2.0  14420396   NaN
# 74      1882.0 -117.717815              1.0  14421732   1.0
# 75      1818.0 -117.723000              NaN  14419850   NaN
# 76      1801.0 -117.681357              1.0  14398127   1.0
# 77      1893.0 -117.703929              1.0  14414283   NaN
# 78      2418.0 -117.684635              2.0  14398006   1.0
# 79      1369.0 -117.727268              1.0  14420592   1.0
# 80      1592.0 -117.677519              1.0  14398770   NaN
# 81      1131.0 -117.706640              1.0  14410437   NaN
# 82      1301.0 -117.701380              1.0  14414399   NaN
# 83      1893.0 -117.705309              1.0  14414155   1.0
# 84      1710.0 -117.723332              1.0  14420407   NaN
# 85      1893.0 -117.700611              1.0  14414415   NaN
# 86      1591.0 -117.698689              1.0  14411519   1.0
# 87      1787.0 -117.694169              1.0  14415817   NaN
# 88      2103.0 -117.721238              1.0  14417639   NaN
# 89      1446.0 -117.722818              1.0  14417088   NaN
# 90      2103.0 -117.719943              1.0  14417553   NaN
# 91      1787.0 -117.691018              1.0  14415833   NaN
# 92      1624.0 -117.712199              1.0  14413898   NaN
# 93      1893.0 -117.699102              1.0  14414368   NaN
# 94      1801.0 -117.681895              1.0  14398676   NaN
# 95      1353.0 -117.714121              1.0  14655162   1.0
# 96      1107.0 -117.723340              1.0  14417041   NaN
# 97      1135.0 -117.715865              1.0  14635898   1.0
# 98      1148.0 -117.689543              NaN  14398854   NaN
# 99      2103.0 -117.721477              1.0  14417645   NaN
#
#                  PropertyType  PropertyTypeID  TaxAssessedOnStructure  \
# 0   Single Family Residential             261                128128.0
# 1   Single Family Residential             261                107801.0
# 2   Single Family Residential             261                174372.0
# 3   Single Family Residential             261                 88517.0
# 4   Single Family Residential             261                 64645.0
# 5   Single Family Residential             261                 94465.0
# 6   Single Family Residential             261                158020.0
# 7   Single Family Residential             261                155860.0
# 8   Single Family Residential             261                121099.0
# 9                 Condominium             266                 84094.0
# 10  Single Family Residential             261                168668.0
# 11  Single Family Residential             261                 85193.0
# 12  Single Family Residential             261                 88175.0
# 13  Single Family Residential             261                194430.0
# 14  Single Family Residential             261                124703.0
# 15  Single Family Residential             261                187356.0
# 16  Single Family Residential             261                144953.0
# 17  Single Family Residential             261                 47915.0
# 18                Condominium             266                 81299.0
# 19  Single Family Residential             261                229905.0
# 20  Single Family Residential             261                 82121.0
# 21  Single Family Residential             261                121099.0
# 22  Single Family Residential             261                265372.0
# 23  Single Family Residential             261                108110.0
# 24  Single Family Residential             261                109983.0
# 25  Single Family Residential             261                138408.0
# 26                Condominium             266                 89985.0
# 27                Condominium             266                 97762.0
# 28                Condominium             266                 76034.0
# 29                Condominium             266                 74520.0
# 30                Condominium             266                 64848.0
# 31  Single Family Residential             261                242992.0
# 32  Single Family Residential             261                143226.0
# 33  Single Family Residential             261                115750.0
# 34                Condominium             266                165580.0
# 35  Single Family Residential             261                160860.0
# 36                Condominium             266                104009.0
# 37  Single Family Residential             261                122804.0
# 38  Single Family Residential             261                 98872.0
# 39                Condominium             266                112014.0
# 40  Single Family Residential             261                141377.0
# 41  Single Family Residential             261                177240.0
# 42  Single Family Residential             261                107320.0
# 43  Single Family Residential             261                162261.0
# 44  Single Family Residential             261                145569.0
# 45  Single Family Residential             261                228593.0
# 46                Condominium             266                123396.0
# 47                Condominium             266                173924.0
# 48  Single Family Residential             261                108228.0
# 49  Single Family Residential             261                152447.0
# 50  Single Family Residential             261                168017.0
# 51  Single Family Residential             261                145020.0
# 52  Single Family Residential             261                118228.0
# 53                Condominium             266                138889.0
# 54  Single Family Residential             261                117732.0
# 55  Single Family Residential             261                174000.0
# 56  Single Family Residential             261                159511.0
# 57                Condominium             266                 77528.0
# 58                Condominium             266                103436.0
# 59  Single Family Residential             261                106127.0
# 60  Single Family Residential             261                156576.0
# 61  Single Family Residential             261                194394.0
# 62  Single Family Residential             261                214782.0
# 63  Single Family Residential             261                240011.0
# 64                Condominium             266                131657.0
# 65                Condominium             266                120953.0
# %%
url = 'http://zillowwebapp-receptive-ens.mybluemix.net/propertydesc?proptype=261'
params = dict()
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)
print(data['Status'])
print(data['Message'])
df=pd.DataFrame(data['results'])
df
# Out:
# 200
# Success
#          PropertyLandUseDesc  PropertyLandUseTypeID
# 0  Single Family Residential                    261

# %% [markdown]
# ## Heating Systems
#
# We can query for types of heating systems available and get the description and its associated ID.
# Following api returns all values as no specific id is provided.**

# %%
url = 'http://zillowwebapp-receptive-ens.mybluemix.net/heatingsystemtype'
params = dict()
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)
print(data['Status'])
print(data['Message'])
df=pd.DataFrame(data['results'])
df
# Out:
# 200
# Success
#    HeatingOrSystemDesc  HeatingOrSystemTypeID
# 0            Baseboard                      1
# 1              Central                      2
# 2                 Coal                      3
# 3           Convection                      4
# 4             Electric                      5
# 5           Forced air                      6
# 6           Floor/Wall                      7
# 7                  Gas                      8
# 8          Geo Thermal                      9
# 9              Gravity                     10
# 10           Heat Pump                     11
# 11           Hot Water                     12
# 12                None                     13
# 13               Other                     14
# 14                 Oil                     15
# 15             Partial                     16
# 16             Propane                     17
# 17             Radiant                     18
# 18               Steam                     19
# 19               Solar                     20
# 20     Space/Suspended                     21
# 21                Vent                     22
# 22        Wood Burning                     23
# 23                 Yes                     24
# 24                Zone                     25

# %% [markdown]
# For specific search provide id number as parameter

# %%
url = 'http://zillowwebapp-receptive-ens.mybluemix.net/heatingsystemtype?heattype=9'
params = dict()
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)
print(data['Status'])
print(data['Message'])
df=pd.DataFrame(data['results'])
df
# Out:
# 200
# Success
#   HeatingOrSystemDesc  HeatingOrSystemTypeID
# 0         Geo Thermal                      9

# %% [markdown]
# ### Aircondition systems
# We can query for types of airconditioning types available and get the description and its associated ID
# Following api returns all values as no specific id is provided.

# %%
url = 'http://zillowwebapp-receptive-ens.mybluemix.net/airconditiontype'
params = dict()
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)
print(data['Status'])
print(data['Message'])
df=pd.DataFrame(data['results'])
df
# Out:
# 200
# Success
#    AirConditioningDesc  AirConditioningTypeID
# 0              Central                      1
# 1        Chilled Water                      2
# 2   Evaporative Cooler                      3
# 3          Geo Thermal                      4
# 4                 None                      5
# 5                Other                      6
# 6     Packaged AC Unit                      7
# 7              Partial                      8
# 8        Refrigeration                      9
# 9          Ventilation                     10
# 10           Wall Unit                     11
# 11         Window Unit                     12
# 12                 Yes                     13

# %% [markdown]
# For specific search provide id number as parameter

# %%
url = 'http://zillowwebapp-receptive-ens.mybluemix.net/airconditiontype?airid=7'
params = dict()
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)
print(data['Status'])
print(data['Message'])
df=pd.DataFrame(data['results'])
df
# Out:
# 200
# Success
#   AirConditioningDesc  AirConditioningTypeID
# 0    Packaged AC Unit                      7

# %% [markdown]
# ## Properties built by year
#
# Returns the count of all properties grouped by the year they were built in. To specifically search for properties built in a particular use the Search API.

# %%
url = 'http://zillowwebapp-receptive-ens.mybluemix.net/propertybyyear'
params = dict()
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)
print(data['Status'])
print(data['Message'])
df=pd.DataFrame(data['results'])
df
# Out:
# 200
# Success
#      numberofhomes  yearbuilt
# 0            48491        NaN
# 1                3     1801.0
# 2                1     1805.0
# 3                2     1806.0
# 4                1     1807.0
# 5                2     1808.0
# 6                1     1810.0
# 7                5     1812.0
# 8                2     1815.0
# 9                2     1819.0
# 10               1     1821.0
# 11               1     1823.0
# 12               1     1824.0
# 13               1     1825.0
# 14               1     1827.0
# 15               1     1828.0
# 16               1     1829.0
# 17               1     1831.0
# 18               1     1833.0
# 19               1     1834.0
# 20               1     1840.0
# 21               1     1853.0
# 22               2     1855.0
# 23               2     1859.0
# 24               2     1862.0
# 25               2     1865.0
# 26               5     1870.0
# 27               2     1874.0
# 28              10     1875.0
# 29               2     1876.0
# 30               1     1877.0
# 31               2     1878.0
# 32               1     1879.0
# 33              50     1880.0
# 34               5     1881.0
# 35              11     1882.0
# 36               9     1883.0
# 37              15     1884.0
# 38             208     1885.0
# 39              41     1886.0
# 40              98     1887.0
# 41             102     1888.0
# 42              39     1889.0
# 43             709     1890.0
# 44              43     1891.0
# 45              80     1892.0
# 46             109     1893.0
# 47             122     1894.0
# 48             745     1895.0
# 49             158     1896.0
# ..             ...        ...
# 119          28216     1966.0
# 120          20926     1967.0
# 121          33137     1968.0
# 122          35549     1969.0
# 123          29795     1970.0
# 124          43022     1971.0
# 125          44434     1972.0
# 126          51464     1973.0
# 127          38336     1974.0
# 128          27694     1975.0
# 129          41782     1976.0
# 130          46663     1977.0
# 131          42673     1978.0
# 132          47514     1979.0
# 133          41392     1980.0
# 134          35411     1981.0
# 135          19472     1982.0
# 136          26456     1983.0
# 137          33927     1984.0
# 138          37479     1985.0
# 139          38548     1986.0
# 140          44851     1987.0
# 141          33742     1988.0
# 142          52520     1989.0
# 143          41200     1990.0
# 144          20166     1991.0
# 145          18013     1992.0
# 146          15209     1993.0
# 147          18761     1994.0
# 148          16527     1995.0
# 149          16937     1996.0
# 150          18032     1997.0
# 151          19337     1998.0
# 152          21653     1999.0
# 153          20518     2000.0
# 154          22120     2001.0
# 155          19347     2002.0
# 156          22690     2003.0
# 157          22005     2004.0
# 158          25809     2005.0
# 159          22636     2006.0
# 160          20086     2007.0
# 161          11704     2008.0
# 162           8554     2009.0
# 163           7439     2010.0
# 164           5604     2011.0
# 165           6594     2012.0
# 166           8165     2013.0
# 167           5693     2014.0
# 168            264     2015.0
#
# [169 rows x 2 columns]

# %% [markdown]
# ** Gives a distribution of properties built by years available**.
# Most constructions are between the years 1950 to 1965, with maximum in 1955.

# %%
df.dropna().plot(x='yearbuilt', y='numberofhomes',kind='bar',figsize=(50,10),color='orange')
plt.show()

# %% [markdown]
# ## Tax value for type of properties
# This api shows the minimun, maximum and average amount of tax associated with each type of property description

# %%
url = 'http://zillowwebapp-receptive-ens.mybluemix.net/propertytax'
params = dict()
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)
print(data['Status'])
print(data['Message'])
df=pd.DataFrame(data['results'])
df
# Out:
# 200
# Success
#                PropertyLandUseDesc   avgtaxvalue  maxtaxvalue  mintaxvalue  \
# 0   Commercial/Office/Residential   6.921381e+05  149613482.0          9.0
# 1         Store/Office (Mixed Use)  2.302458e+06  282786000.0          9.0
# 2                 "Duplex (2 Units  3.447795e+05   18751008.0          9.0
# 3                "Triplex (3 Units  3.794732e+05   12750000.0          9.0
# 4             "Quadruplex (4 Units  4.713317e+05   17696310.0          9.0
# 5              Residential General  1.960106e+06  164246219.0         10.0
# 6        Single Family Residential  4.379277e+05   96939552.0          1.0
# 7                      Mobile Home  4.066309e+04    5369681.0          1.0
# 8                        Townhouse  4.750949e+05   16236885.0      85182.0
# 9                     Cluster Home  2.733164e+05    2868908.0       8567.0
# 10                     Condominium  3.484400e+05   51066012.0          8.0
# 11                     Cooperative  3.238325e+05    3797881.0      21487.0
# 12        Planned Unit Development  4.706173e+05   26213486.0          1.0
# 13         Residential Common Area           NaN          NaN          NaN
# 14                   "Manufactured  1.738555e+05     750000.0      16207.0
#
#     propertylandusetypeid
# 0                      31
# 1                      47
# 2                     246
# 3                     247
# 4                     248
# 5                     260
# 6                     261
# 7                     263
# 8                     264
# 9                     265
# 10                    266
# 11                    267
# 12                    269
# 13                    270
# 14                    275

# %%
df.plot.bar(x='PropertyLandUseDesc',y='avgtaxvalue',color='green',figsize=(18,10))
plt.show()
